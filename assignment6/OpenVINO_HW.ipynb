# %% [markdown]
# # OpenVINO (50 баллов)
#
# ## Установим Зависимости

# %%
# !pip install -U openvino nncf
# # или пре-релизная версия:
# !pip install --pre -U openvino --extra-index-url https://storage.openvinotoolkit.org/simple/wheels/nightly git+https://github.com/openvinotoolkit/nncf.git

# !pip install transformers[torch] datasets evaluate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openvino in /home/gvasserm/.local/lib/python3.10/site-packages (2024.0.0)
# Requirement already satisfied: nncf in /home/gvasserm/.local/lib/python3.10/site-packages (2.9.0)
# Requirement already satisfied: numpy>=1.16.6 in /home/gvasserm/.local/lib/python3.10/site-packages (from openvino) (1.26.4)
# Requirement already satisfied: openvino-telemetry>=2023.2.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from openvino) (2024.1.0)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from openvino) (21.3)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/lib/python3/dist-packages (from nncf) (3.2.0)
# Requirement already satisfied: jstyleson>=0.0.2 in /home/gvasserm/.local/lib/python3.10/site-packages (from nncf) (0.0.2)
# Requirement already satisfied: natsort>=7.1.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from nncf) (8.4.0)
# Requirement already satisfied: networkx<=3.1,>=2.6 in /home/gvasserm/.local/lib/python3.10/site-packages (from nncf) (3.1)
# Requirement already satisfied: ninja<1.11,>=1.10.0.post2 in /home/gvasserm/.local/lib/python3.10/site-packages (from nncf) (1.10.2.4)
# Requirement already satisfied: pandas<2.2,>=1.1.5 in /home/gvasserm/.local/lib/python3.10/site-packages (from nncf) (2.1.4)
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from nncf) (5.9.0)
# Requirement already satisfied: pydot>=1.4.1 in /usr/lib/python3/dist-packages (from nncf) (1.4.2)
# Requirement already satisfied: pymoo>=0.6.0.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from nncf) (0.6.1.1)
# Requirement already satisfied: rich>=13.5.2 in /home/gvasserm/.local/lib/python3.10/site-packages (from nncf) (13.7.0)
# Requirement already satisfied: scikit-learn>=0.24.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from nncf) (1.4.1.post1)
# Requirement already satisfied: scipy>=1.3.2 in /home/gvasserm/.local/lib/python3.10/site-packages (from nncf) (1.11.4)
# Requirement already satisfied: texttable>=1.6.3 in /usr/lib/python3/dist-packages (from nncf) (1.6.4)
# Requirement already satisfied: tqdm>=4.54.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from nncf) (4.66.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gvasserm/.local/lib/python3.10/site-packages (from pandas<2.2,>=1.1.5->nncf) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas<2.2,>=1.1.5->nncf) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from pandas<2.2,>=1.1.5->nncf) (2024.1)
# Requirement already satisfied: matplotlib>=3 in /home/gvasserm/.local/lib/python3.10/site-packages (from pymoo>=0.6.0.1->nncf) (3.8.3)
# Requirement already satisfied: autograd>=1.4 in /home/gvasserm/.local/lib/python3.10/site-packages (from pymoo>=0.6.0.1->nncf) (1.6.2)
# Requirement already satisfied: cma==3.2.2 in /home/gvasserm/.local/lib/python3.10/site-packages (from pymoo>=0.6.0.1->nncf) (3.2.2)
# Requirement already satisfied: alive-progress in /home/gvasserm/.local/lib/python3.10/site-packages (from pymoo>=0.6.0.1->nncf) (3.1.5)
# Requirement already satisfied: dill in /home/gvasserm/.local/lib/python3.10/site-packages (from pymoo>=0.6.0.1->nncf) (0.3.8)
# Requirement already satisfied: Deprecated in /home/gvasserm/.local/lib/python3.10/site-packages (from pymoo>=0.6.0.1->nncf) (1.2.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from rich>=13.5.2->nncf) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from rich>=13.5.2->nncf) (2.17.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from scikit-learn>=0.24.0->nncf) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from scikit-learn>=0.24.0->nncf) (3.3.0)
# Requirement already satisfied: future>=0.15.2 in /usr/lib/python3/dist-packages (from autograd>=1.4->pymoo>=0.6.0.1->nncf) (0.18.2)
# Requirement already satisfied: mdurl~=0.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.5.2->nncf) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from matplotlib>=3->pymoo>=0.6.0.1->nncf) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/gvasserm/.local/lib/python3.10/site-packages (from matplotlib>=3->pymoo>=0.6.0.1->nncf) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from matplotlib>=3->pymoo>=0.6.0.1->nncf) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from matplotlib>=3->pymoo>=0.6.0.1->nncf) (1.4.5)
# Requirement already satisfied: pillow>=8 in /home/gvasserm/.local/lib/python3.10/site-packages (from matplotlib>=3->pymoo>=0.6.0.1->nncf) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3->pymoo>=0.6.0.1->nncf) (2.4.7)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas<2.2,>=1.1.5->nncf) (1.16.0)
# Requirement already satisfied: about-time==4.2.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from alive-progress->pymoo>=0.6.0.1->nncf) (4.2.1)
# Requirement already satisfied: grapheme==0.6.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from alive-progress->pymoo>=0.6.0.1->nncf) (0.6.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/gvasserm/.local/lib/python3.10/site-packages (from Deprecated->pymoo>=0.6.0.1->nncf) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in /home/gvasserm/.local/lib/python3.10/site-packages (2.18.0)
# Requirement already satisfied: evaluate in /home/gvasserm/.local/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: transformers[torch] in /home/gvasserm/.local/lib/python3.10/site-packages (4.38.1)
# Requirement already satisfied: filelock in /home/gvasserm/.local/lib/python3.10/site-packages (from transformers[torch]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/gvasserm/.local/lib/python3.10/site-packages (from transformers[torch]) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /home/gvasserm/.local/lib/python3.10/site-packages (from transformers[torch]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from transformers[torch]) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/gvasserm/.local/lib/python3.10/site-packages (from transformers[torch]) (2023.12.25)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers[torch]) (2.25.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/gvasserm/.local/lib/python3.10/site-packages (from transformers[torch]) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from transformers[torch]) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/gvasserm/.local/lib/python3.10/site-packages (from transformers[torch]) (4.66.2)
# Requirement already satisfied: torch in /home/gvasserm/.local/lib/python3.10/site-packages (from transformers[torch]) (2.2.2)
# Requirement already satisfied: accelerate>=0.21.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from transformers[torch]) (0.29.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from datasets) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/gvasserm/.local/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/gvasserm/.local/lib/python3.10/site-packages (from datasets) (2.1.4)
# Requirement already satisfied: xxhash in /home/gvasserm/.local/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /home/gvasserm/.local/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.2.0,>=2023.1.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from fsspec[http]<=2024.2.0,>=2023.1.0->datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in /home/gvasserm/.local/lib/python3.10/site-packages (from datasets) (3.9.3)
# Requirement already satisfied: responses<0.19 in /home/gvasserm/.local/lib/python3.10/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/gvasserm/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp->datasets) (21.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/gvasserm/.local/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/gvasserm/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (4.10.0)
# Requirement already satisfied: urllib3>=1.25.10 in /home/gvasserm/.local/lib/python3.10/site-packages (from responses<0.19->evaluate) (1.26.18)
# Requirement already satisfied: sympy in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (3.1)
# Requirement already satisfied: jinja2 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from torch->transformers[torch]) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/gvasserm/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.3.101)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gvasserm/.local/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/gvasserm/.local/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: idna>=2.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp->datasets) (2.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gvasserm/.local/lib/python3.10/site-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/gvasserm/.local/lib/python3.10/site-packages (from sympy->torch->transformers[torch]) (1.3.0)

# %% [markdown]
# ## Скачиваем Предобученную Модель
#
# Выберите классификационную модель из [Huggingface Hub](https://huggingface.co/models?pipeline_tag=text-classification&sort=trending&search=sst2), либо возьмите модель по умолчанию. Этот ноутбук сделан с рассчётом модель, натренированную на [sst2](https://huggingface.co/datasets/nyu-mll/glue/viewer/sst2) датасете. Если выберете другую модель и датасет, перепешите соответствующие блоки проверки accuracy. Единственное ограничение - модель должна быть трансформер энкодером.

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

model_id = "philschmid/MiniLM-L6-H384-uncased-sst2"
tokenizer = AutoTokenizer.from_pretrained(model_id)
hf_model = AutoModelForSequenceClassification.from_pretrained(model_id)

# %%
hf_model.save_pretrained("base_model")
tokenizer.save_pretrained("tokenizer")
# Out:
# ('tokenizer/tokenizer_config.json',
#  'tokenizer/special_tokens_map.json',
#  'tokenizer/vocab.txt',
#  'tokenizer/added_tokens.json',
#  'tokenizer/tokenizer.json')

# %%
tokenizer
# Out:
# BertTokenizerFast(name_or_path='philschmid/MiniLM-L6-H384-uncased-sst2', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	100: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	101: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	102: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	103: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %% [markdown]
# ## Конвертируем Модель в OpenVINO (5 баллов)

# %%
import openvino as ov

# готовим пример входа
text_input = ["I love accelerating networks"]
hf_input = tokenizer(text_input, return_tensors="pt")
ov_model = ov.convert_model(hf_model, example_input=hf_input.data)
ov.save_model(ov_model, "model.xml")

compiled_model = ov.compile_model(ov_model)
print(compiled_model(hf_input.data))
# Out:
# /home/gvasserm/.local/lib/python3.10/site-packages/transformers/modeling_utils.py:4193: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# {<ConstOutput: names[logits] shape[?,2] type: f32>: array([[-3.0815837,  2.9208455]], dtype=float32)}

# %% [markdown]
# Провалидируем предсказания сконвертированной модели:

# %%
import torch
import numpy as np
from datasets import load_dataset
import evaluate


val_dataset = load_dataset("glue", "sst2", split="validation")
accuracy = evaluate.load("accuracy")

@torch.no_grad
def accuracy_evaluate(model, dataset=val_dataset, accuracy=accuracy):   
    for sample in dataset:
        tokenized = {**tokenizer(sample["sentence"], return_tensors="pt")}
        logits = model(tokenized)
        pred = np.argmax(logits, axis=1)
        accuracy.add(references=sample["label"], predictions=pred)

    return accuracy.compute()

print(f"PyTorch:  {accuracy_evaluate(lambda x: hf_model(**x).logits)}")
print(f"OpenVINO: {accuracy_evaluate(lambda x: compiled_model(x)[compiled_model.output()])}")
# Out:
# PyTorch:  {'accuracy': 0.9013761467889908}
# OpenVINO: {'accuracy': 0.9013761467889908}

# %% [markdown]
# ## Benchmark (5 баллов)
#
# Добавьте несколько инференсов в бенчмарк для того, чтобы получить более точные результаты.

# %%
from time import perf_counter
from statistics import median

@torch.no_grad
def benchmark(model, dataset, num_warmup=10):
    tokenized_dataset = [{**tokenizer(sample["sentence"], return_tensors="pt")} for sample in dataset]

    # add warmup step
    for i in range(num_warmup):
        warmup_data = tokenized_dataset[i % len(tokenized_dataset)]
        _ = model(warmup_data)
    
    times = []
    for data in tokenized_dataset:
        start = perf_counter()
        model(data)
        end = perf_counter()
        times.append(end - start)

    return (
        f"{sum(times):.5f}s, FPS={(len(dataset) / sum(times)):.3f}, "
        f"latency: {min(times):.5f}s, {median(times):.5f}s, {max(times):.5f}s"
    )

print("Pytorch:  ", benchmark(lambda x: hf_model(**x), val_dataset))
print("Openvino: ", benchmark(lambda x: compiled_model(x), val_dataset))
# Out:
# Pytorch:   3.68378s, FPS=236.714, latency: 0.00256s, 0.00412s, 0.01453s
# Openvino:  2.62611s, FPS=332.051, latency: 0.00178s, 0.00291s, 0.00764s

# %% [markdown]
# ## Inference Hints (3 балла)
#
# Скомпилируйте модель с разными инференс хинтами и сравните результаты бенчмарка. Не забудьте указать "CPU" в качестве таргета.

# %%
import openvino.properties as props
import openvino.properties.hint as hints

core = ov.Core()
print(core.available_devices)
#core.set_property("CPU", {hints.execution_mode: hints.ExecutionMode.PERFORMANCE})
config = {hints.performance_mode: hints.PerformanceMode.THROUGHPUT}
compiled_througput = core.compile_model(ov_model, "AUTO", config)
print("Openvino: ", benchmark(lambda x: compiled_througput(x), val_dataset))
# Out:
# ['CPU', 'GPU']
# Openvino:  4.42930s, FPS=196.871, latency: 0.00228s, 0.00441s, 0.01701s

# %%
config = {hints.performance_mode: hints.PerformanceMode.THROUGHPUT}
compiled_througput = core.compile_model(ov_model, "CPU", config)
print("Openvino: ", benchmark(lambda x: compiled_througput(x), val_dataset))
# Out:
# Openvino:  2.78592s, FPS=313.002, latency: 0.00178s, 0.00312s, 0.00608s

# %% [markdown]
# LATENCY HINT

# %%
config = {hints.performance_mode: hints.PerformanceMode.LATENCY}
compiled_latency = core.compile_model(ov_model, "CPU", config)
print("Openvino: ", benchmark(lambda x: compiled_latency(x), val_dataset))
# Out:
# Openvino:  2.14571s, FPS=406.393, latency: 0.00131s, 0.00242s, 0.00428s

# %% [markdown]
# ## Async Inference
#
# Переписать бенчмарк под асинхронный инференс. Он должен принимать на вход асинхронную очередь и датасет.
#
# ### Простой Бенчмарк (5 баллов)
# Простая версия бенчмарка должна замерить FPS:

# %%
from typing import Dict, Any, Optional


def completion_callback(
    infer_request: ov.InferRequest, user_data: Optional[Dict[str, Any]] = None
) -> None:
    if user_data is not None:
        user_data['results'].append(infer_request.results)

infer_queue = ov.AsyncInferQueue(compiled_througput)
infer_queue.set_callback(completion_callback)

def simple_benchmark_async(queue, dataset):
    tokenized_dataset = [{**tokenizer(sample["sentence"], return_tensors="np")} for sample in dataset]
    user_data = {'results': []}

    # Start timing
    start_time = perf_counter()

    # Start async inference
    for data in tokenized_dataset: 
        inputs = {k: v for k, v in data.items()} 
        queue.start_async(inputs, user_data)

    # Wait for all requests to complete
    queue.wait_all()

    # Compute elapsed time
    elapsed = perf_counter() - start_time

    return f"{elapsed:.5f}s, FPS={(len(dataset) / elapsed):.3f}"

print("Openvino: ", simple_benchmark_async(infer_queue, val_dataset))
# Out:
# Openvino:  1.11363s, FPS=783.022

# %% [markdown]
# ### Добавить Измерение latency В Асинхронный Бенчмарк (14 баллов)
#
# Используйте `completion_callback` для подсчёта latency.

# %%
def completion_callback(
    infer_request: ov.InferRequest,
    user_data: Dict[str, Any],
) -> None:
    if user_data is not None:
        user_data['results'].append(infer_request.results)


infer_queue.set_callback(completion_callback)

def benchmark_async(queue, dataset):
    tokenized_dataset = [{**tokenizer(sample["sentence"], return_tensors="np")} for sample in dataset]
    times = [0 for _ in range(len(dataset))]

    user_data = {'results': []}

    start_time = perf_counter()

    # Start async inference
    for i, data in enumerate(tokenized_dataset):
        start = perf_counter()
        queue.start_async({k: v for k, v in data.items()}, user_data)
        end = perf_counter()
        times[i] = (end - start)

    # Ensure all requests are completed
    queue.wait_all()

    elapsed = perf_counter() - start_time

    return (
        f"{elapsed:.5f}s, FPS={(len(dataset) / elapsed):.3f}, "
        f"latency: {min(times):.5f}s, {median(times):.5f}s, {max(times):.5f}s"
    )

print("Openvino: ", benchmark_async(infer_queue, val_dataset))
# Out:
# Openvino:  1.11316s, FPS=783.357, latency: 0.00006s, 0.00080s, 0.00592s

# %% [markdown]
# ## Benchmark App
#
# ### Измерьте Производительность Модели с Помощью CLI benchmark_app (1 балл)
#
# Чтобы не ждать по минуте можете использовать флаг `-t 30`. Выполнение какого слоя занимает больше всего времени?

# %%
! benchmark_app -m model.xml -t 30 -shape [1,128] -pc -pcsort "sort"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [Step 1/11] Parsing and validating input arguments
# [ INFO ] Parsing input parameters
# [Step 2/11] Loading OpenVINO Runtime
# [ INFO ] OpenVINO:
# [ INFO ] Build ................................. 2024.0.0-14509-34caeefd078-releases/2024/0
# [ INFO ]
# [ INFO ] Device info:
# [ INFO ] CPU
# [ INFO ] Build ................................. 2024.0.0-14509-34caeefd078-releases/2024/0
# [ INFO ]
# [ INFO ]
# [Step 3/11] Setting device configuration
# [ WARNING ] Performance hint was not explicitly specified in command line. Device(CPU) performance hint will be set to PerformanceMode.THROUGHPUT.
# [Step 4/11] Reading model files
# [ INFO ] Loading model files
# [ INFO ] Read model took 8.04 ms
# [ INFO ] Original model I/O parameters:
# [ INFO ] Model inputs:
# [ INFO ]     input_ids (node: input_ids) : i64 / [...] / [?,?]
# [ INFO ]     attention_mask (node: attention_mask) : i64 / [...] / [?,?]
# [ INFO ]     token_type_ids (node: token_type_ids) : i64 / [...] / [?,?]
# [ INFO ] Model outputs:
# [ INFO ]     logits (node: __module.classifier/aten::linear/Add) : f32 / [...] / [?,2]
# [Step 5/11] Resizing model to match image sizes and given batch
# [ INFO ] Model batch size: 1
# [ INFO ] Reshaping model: 'input_ids': [1,128], 'attention_mask': [1,128], 'token_type_ids': [1,128]
# [ INFO ] Reshape model took 2.02 ms
# [Step 6/11] Configuring input of the model
# [ INFO ] Model inputs:
# [ INFO ]     input_ids (node: input_ids) : i64 / [...] / [1,128]
# [ INFO ]     attention_mask (node: attention_mask) : i64 / [...] / [1,128]
# [ INFO ]     token_type_ids (node: token_type_ids) : i64 / [...] / [1,128]
# [ INFO ] Model outputs:
# [ INFO ]     logits (node: __module.classifier/aten::linear/Add) : f32 / [...] / [1,2]
# [Step 7/11] Loading the model to the device
# [ INFO ] Compile model took 142.29 ms
# [Step 8/11] Querying optimal runtime parameters
# [ INFO ] Model:
# [ INFO ]   NETWORK_NAME: Model0
# [ INFO ]   OPTIMAL_NUMBER_OF_INFER_REQUESTS: 16
# [ INFO ]   NUM_STREAMS: 16
# [ INFO ]   AFFINITY: Affinity.HYBRID_AWARE
# [ INFO ]   INFERENCE_NUM_THREADS: 20
# [ INFO ]   PERF_COUNT: YES
# [ INFO ]   INFERENCE_PRECISION_HINT: <Type: 'float32'>
# [ INFO ]   PERFORMANCE_HINT: THROUGHPUT
# [ INFO ]   EXECUTION_MODE_HINT: ExecutionMode.PERFORMANCE
# [ INFO ]   PERFORMANCE_HINT_NUM_REQUESTS: 0
# [ INFO ]   ENABLE_CPU_PINNING: True
# [ INFO ]   SCHEDULING_CORE_TYPE: SchedulingCoreType.ANY_CORE
# [ INFO ]   ENABLE_HYPER_THREADING: True
# [ INFO ]   EXECUTION_DEVICES: ['CPU']
# [ INFO ]   CPU_DENORMALS_OPTIMIZATION: False
# [ INFO ]   LOG_LEVEL: Level.NO
# [ INFO ]   CPU_SPARSE_WEIGHTS_DECOMPRESSION_RATE: 1.0
# [ INFO ]   DYNAMIC_QUANTIZATION_GROUP_SIZE: 0
# [ INFO ]   KV_CACHE_PRECISION: <Type: 'float16'>
# [Step 9/11] Creating infer requests and preparing input tensors
# [ WARNING ] No input files were given for input 'input_ids'!. This input will be filled with random values!
# [ WARNING ] No input files were given for input 'attention_mask'!. This input will be filled with random values!
# [ WARNING ] No input files were given for input 'token_type_ids'!. This input will be filled with random values!
# [ INFO ] Fill input 'input_ids' with random values
# [ INFO ] Fill input 'attention_mask' with random values
# [ INFO ] Fill input 'token_type_ids' with random values
# [Step 10/11] Measuring performance (Start inference asynchronously, 16 inference requests, limits: 30000 ms duration)
# [ INFO ] Benchmarking in inference only mode (inputs filling are not included in measurement loop).
# [ INFO ] First inference took 34.38 ms
# [Step 11/11] Dumping statistics report
# [ INFO ] Performance counts sorted for 0-th infer request
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.724      cpuTime (ms): 3.724     proportion: 5.24%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.724      cpuTime (ms): 3.724     proportion: 5.24%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.704      cpuTime (ms): 3.704     proportion: 5.21%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.658      cpuTime (ms): 3.658     proportion: 5.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.650      cpuTime (ms): 3.650     proportion: 5.13%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.644      cpuTime (ms): 3.644     proportion: 5.13%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.594      cpuTime (ms): 3.594     proportion: 5.06%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.562      cpuTime (ms): 3.562     proportion: 5.01%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.558      cpuTime (ms): 3.558     proportion: 5.01%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.531      cpuTime (ms): 3.531     proportion: 4.97%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.530      cpuTime (ms): 3.530     proportion: 4.97%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.526      cpuTime (ms): 3.526     proportion: 4.96%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.865      cpuTime (ms): 0.865     proportion: 1.22%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.848      cpuTime (ms): 0.848     proportion: 1.19%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.845      cpuTime (ms): 0.845     proportion: 1.19%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.830      cpuTime (ms): 0.830     proportion: 1.17%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.826      cpuTime (ms): 0.826     proportion: 1.16%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.825      cpuTime (ms): 0.825     proportion: 1.16%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.823      cpuTime (ms): 0.823     proportion: 1.16%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.823      cpuTime (ms): 0.823     proportion: 1.16%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.822      cpuTime (ms): 0.822     proportion: 1.16%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.819      cpuTime (ms): 0.819     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.818      cpuTime (ms): 0.818     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.817      cpuTime (ms): 0.817     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.816      cpuTime (ms): 0.816     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.815      cpuTime (ms): 0.815     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.815      cpuTime (ms): 0.815     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.813      cpuTime (ms): 0.813     proportion: 1.14%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.813      cpuTime (ms): 0.813     proportion: 1.14%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.812      cpuTime (ms): 0.812     proportion: 1.14%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.810      cpuTime (ms): 0.810     proportion: 1.14%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.809      cpuTime (ms): 0.809     proportion: 1.14%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.809      cpuTime (ms): 0.809     proportion: 1.14%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.808      cpuTime (ms): 0.808     proportion: 1.14%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.806      cpuTime (ms): 0.806     proportion: 1.13%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.802      cpuTime (ms): 0.802     proportion: 1.13%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.369      cpuTime (ms): 0.369     proportion: 0.52%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.341      cpuTime (ms): 0.341     proportion: 0.48%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.336      cpuTime (ms): 0.336     proportion: 0.47%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.324      cpuTime (ms): 0.324     proportion: 0.46%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.323      cpuTime (ms): 0.323     proportion: 0.45%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.322      cpuTime (ms): 0.322     proportion: 0.45%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.309      cpuTime (ms): 0.309     proportion: 0.43%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.294      cpuTime (ms): 0.294     proportion: 0.41%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.288      cpuTime (ms): 0.288     proportion: 0.41%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.286      cpuTime (ms): 0.286     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.285      cpuTime (ms): 0.285     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.284      cpuTime (ms): 0.284     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.283      cpuTime (ms): 0.283     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.282      cpuTime (ms): 0.282     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.282      cpuTime (ms): 0.282     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.281      cpuTime (ms): 0.281     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.281      cpuTime (ms): 0.281     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.281      cpuTime (ms): 0.281     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.126      cpuTime (ms): 0.126     proportion: 0.18%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.104      cpuTime (ms): 0.104     proportion: 0.15%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.103      cpuTime (ms): 0.103     proportion: 0.14%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.102      cpuTime (ms): 0.102     proportion: 0.14%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.098      cpuTime (ms): 0.098     proportion: 0.14%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.098      cpuTime (ms): 0.098     proportion: 0.14%
# __module.bert.po...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.059      cpuTime (ms): 0.059     proportion: 0.08%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.046      cpuTime (ms): 0.046     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.046      cpuTime (ms): 0.046     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.044      cpuTime (ms): 0.044     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.044      cpuTime (ms): 0.044     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.042      cpuTime (ms): 0.042     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.042      cpuTime (ms): 0.042     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.039      cpuTime (ms): 0.039     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.038      cpuTime (ms): 0.038     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.038      cpuTime (ms): 0.038     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.037      cpuTime (ms): 0.037     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.037      cpuTime (ms): 0.037     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.034      cpuTime (ms): 0.034     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.033      cpuTime (ms): 0.033     proportion: 0.05%
# __module.bert.em...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.04%
# __module.bert.em...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.em...  Status.EXECUTED      layerType: Gather               execType: ref_any_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.028      cpuTime (ms): 0.028     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.028      cpuTime (ms): 0.028     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.027      cpuTime (ms): 0.027     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.026      cpuTime (ms): 0.026     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.026      cpuTime (ms): 0.026     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.023      cpuTime (ms): 0.023     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.022      cpuTime (ms): 0.022     proportion: 0.03%
# __module.bert.em...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.021      cpuTime (ms): 0.021     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.021      cpuTime (ms): 0.021     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.019      cpuTime (ms): 0.019     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.018      cpuTime (ms): 0.018     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.015      cpuTime (ms): 0.015     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.015      cpuTime (ms): 0.015     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.015      cpuTime (ms): 0.015     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.015      cpuTime (ms): 0.015     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.015      cpuTime (ms): 0.015     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.011      cpuTime (ms): 0.011     proportion: 0.02%
# __module.bert.em...  Status.EXECUTED      layerType: Gather               execType: ref_any_f32          realTime (ms): 0.010      cpuTime (ms): 0.010     proportion: 0.01%
# __module.classif...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.006      cpuTime (ms): 0.006     proportion: 0.01%
# __module.bert.em...  Status.EXECUTED      layerType: Convert              execType: ref_i64              realTime (ms): 0.005      cpuTime (ms): 0.005     proportion: 0.01%
# Convert_4448         Status.EXECUTED      layerType: Convert              execType: ref_i64              realTime (ms): 0.002      cpuTime (ms): 0.002     proportion: N/A%
# __module.bert/at...  Status.EXECUTED      layerType: Convert              execType: ref_i32              realTime (ms): 0.002      cpuTime (ms): 0.002     proportion: N/A%
# __module.bert.em...  Status.EXECUTED      layerType: Convert              execType: ref_i64              realTime (ms): 0.002      cpuTime (ms): 0.002     proportion: N/A%
# input_ids            Status.NOT_RUN       layerType: Parameter            execType: unknown_i64          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# attention_mask       Status.NOT_RUN       layerType: Parameter            execType: unknown_i64          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert/at...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# token_type_ids       Status.NOT_RUN       layerType: Parameter            execType: unknown_i64          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Multiply_5226        Status.NOT_RUN       layerType: PowerStatic          execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Multiply_5229        Status.NOT_RUN       layerType: PowerStatic          execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Multiply_5232        Status.NOT_RUN       layerType: PowerStatic          execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Multiply_5235        Status.NOT_RUN       layerType: PowerStatic          execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Multiply_5238        Status.NOT_RUN       layerType: PowerStatic          execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Multiply_5241        Status.NOT_RUN       layerType: PowerStatic          execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.po...  Status.NOT_RUN       layerType: Gather               execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.po...  Status.NOT_RUN       layerType: Tanh                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Result_2209          Status.NOT_RUN       layerType: Result               execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Total time:       71.087 milliseconds
# Total CPU time:   71.087 milliseconds
# Total proportion: 100.00 %
#
# [ INFO ] Performance counts sorted for 1-th infer request
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.987      cpuTime (ms): 3.987     proportion: 5.34%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.913      cpuTime (ms): 3.913     proportion: 5.24%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.882      cpuTime (ms): 3.882     proportion: 5.20%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.881      cpuTime (ms): 3.881     proportion: 5.20%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.829      cpuTime (ms): 3.829     proportion: 5.13%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.828      cpuTime (ms): 3.828     proportion: 5.13%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.767      cpuTime (ms): 3.767     proportion: 5.04%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.767      cpuTime (ms): 3.767     proportion: 5.04%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.722      cpuTime (ms): 3.722     proportion: 4.98%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.694      cpuTime (ms): 3.694     proportion: 4.95%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.688      cpuTime (ms): 3.688     proportion: 4.94%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.653      cpuTime (ms): 3.653     proportion: 4.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.898      cpuTime (ms): 0.898     proportion: 1.20%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.897      cpuTime (ms): 0.897     proportion: 1.20%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.885      cpuTime (ms): 0.885     proportion: 1.19%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.884      cpuTime (ms): 0.884     proportion: 1.18%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.881      cpuTime (ms): 0.881     proportion: 1.18%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.880      cpuTime (ms): 0.880     proportion: 1.18%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.876      cpuTime (ms): 0.876     proportion: 1.17%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.868      cpuTime (ms): 0.868     proportion: 1.16%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.868      cpuTime (ms): 0.868     proportion: 1.16%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.865      cpuTime (ms): 0.865     proportion: 1.16%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.864      cpuTime (ms): 0.864     proportion: 1.16%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.862      cpuTime (ms): 0.862     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.862      cpuTime (ms): 0.862     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.861      cpuTime (ms): 0.861     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.859      cpuTime (ms): 0.859     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.857      cpuTime (ms): 0.857     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.854      cpuTime (ms): 0.854     proportion: 1.14%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.853      cpuTime (ms): 0.853     proportion: 1.14%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.850      cpuTime (ms): 0.850     proportion: 1.14%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.845      cpuTime (ms): 0.845     proportion: 1.13%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.844      cpuTime (ms): 0.844     proportion: 1.13%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.841      cpuTime (ms): 0.841     proportion: 1.13%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.838      cpuTime (ms): 0.838     proportion: 1.12%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.825      cpuTime (ms): 0.825     proportion: 1.10%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.355      cpuTime (ms): 0.355     proportion: 0.48%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.355      cpuTime (ms): 0.355     proportion: 0.48%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.343      cpuTime (ms): 0.343     proportion: 0.46%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.343      cpuTime (ms): 0.343     proportion: 0.46%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.342      cpuTime (ms): 0.342     proportion: 0.46%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.333      cpuTime (ms): 0.333     proportion: 0.45%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.308      cpuTime (ms): 0.308     proportion: 0.41%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.308      cpuTime (ms): 0.308     proportion: 0.41%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.302      cpuTime (ms): 0.302     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.297      cpuTime (ms): 0.297     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.296      cpuTime (ms): 0.296     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.295      cpuTime (ms): 0.295     proportion: 0.40%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.294      cpuTime (ms): 0.294     proportion: 0.39%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.294      cpuTime (ms): 0.294     proportion: 0.39%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.293      cpuTime (ms): 0.293     proportion: 0.39%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.292      cpuTime (ms): 0.292     proportion: 0.39%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.289      cpuTime (ms): 0.289     proportion: 0.39%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.287      cpuTime (ms): 0.287     proportion: 0.38%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.140      cpuTime (ms): 0.140     proportion: 0.19%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.111      cpuTime (ms): 0.111     proportion: 0.15%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.104      cpuTime (ms): 0.104     proportion: 0.14%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.104      cpuTime (ms): 0.104     proportion: 0.14%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.104      cpuTime (ms): 0.104     proportion: 0.14%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.101      cpuTime (ms): 0.101     proportion: 0.14%
# __module.bert.po...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.071      cpuTime (ms): 0.071     proportion: 0.10%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.049      cpuTime (ms): 0.049     proportion: 0.07%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.048      cpuTime (ms): 0.048     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.048      cpuTime (ms): 0.048     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.047      cpuTime (ms): 0.047     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.046      cpuTime (ms): 0.046     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.046      cpuTime (ms): 0.046     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.044      cpuTime (ms): 0.044     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.044      cpuTime (ms): 0.044     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.042      cpuTime (ms): 0.042     proportion: 0.06%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.038      cpuTime (ms): 0.038     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.037      cpuTime (ms): 0.037     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.037      cpuTime (ms): 0.037     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.036      cpuTime (ms): 0.036     proportion: 0.05%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.035      cpuTime (ms): 0.035     proportion: 0.05%
# ...
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_f32         realTime (ms): 0.030      cpuTime (ms): 0.030     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.029      cpuTime (ms): 0.029     proportion: 0.04%
# __module.bert.em...  Status.EXECUTED      layerType: Gather               execType: ref_any_f32          realTime (ms): 0.028      cpuTime (ms): 0.028     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.028      cpuTime (ms): 0.028     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.028      cpuTime (ms): 0.028     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.028      cpuTime (ms): 0.028     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.027      cpuTime (ms): 0.027     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.027      cpuTime (ms): 0.027     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.025      cpuTime (ms): 0.025     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.022      cpuTime (ms): 0.022     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.022      cpuTime (ms): 0.022     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.021      cpuTime (ms): 0.021     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.021      cpuTime (ms): 0.021     proportion: 0.03%
# __module.bert.em...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_f32          realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.020      cpuTime (ms): 0.020     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.019      cpuTime (ms): 0.019     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.016      cpuTime (ms): 0.016     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.016      cpuTime (ms): 0.016     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.015      cpuTime (ms): 0.015     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.015      cpuTime (ms): 0.015     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.015      cpuTime (ms): 0.015     proportion: 0.02%
# __module.bert.em...  Status.EXECUTED      layerType: Gather               execType: ref_any_f32          realTime (ms): 0.011      cpuTime (ms): 0.011     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.011      cpuTime (ms): 0.011     proportion: 0.02%
# __module.classif...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.005      cpuTime (ms): 0.005     proportion: 0.01%
# __module.bert.em...  Status.EXECUTED      layerType: Convert              execType: ref_i64              realTime (ms): 0.004      cpuTime (ms): 0.004     proportion: 0.01%
# Convert_4448         Status.EXECUTED      layerType: Convert              execType: ref_i64              realTime (ms): 0.002      cpuTime (ms): 0.002     proportion: N/A%
# __module.bert/at...  Status.EXECUTED      layerType: Convert              execType: ref_i32              realTime (ms): 0.002      cpuTime (ms): 0.002     proportion: N/A%
# __module.bert.em...  Status.EXECUTED      layerType: Convert              execType: ref_i64              realTime (ms): 0.002      cpuTime (ms): 0.002     proportion: N/A%
# input_ids            Status.NOT_RUN       layerType: Parameter            execType: unknown_i64          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# attention_mask       Status.NOT_RUN       layerType: Parameter            execType: unknown_i64          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert/at...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# token_type_ids       Status.NOT_RUN       layerType: Parameter            execType: unknown_i64          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Multiply_5226        Status.NOT_RUN       layerType: PowerStatic          execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Multiply_5229        Status.NOT_RUN       layerType: PowerStatic          execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Multiply_5232        Status.NOT_RUN       layerType: PowerStatic          execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Multiply_5235        Status.NOT_RUN       layerType: PowerStatic          execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Multiply_5238        Status.NOT_RUN       layerType: PowerStatic          execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Multiply_5241        Status.NOT_RUN       layerType: PowerStatic          execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.po...  Status.NOT_RUN       layerType: Gather               execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.po...  Status.NOT_RUN       layerType: Tanh                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Result_2209          Status.NOT_RUN       layerType: Result               execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Total time:       69.771 milliseconds
# Total CPU time:   69.771 milliseconds
# Total proportion: 100.00 %
#
# [ INFO ] Execution Devices:['CPU']
# [ INFO ] Count:            6816 iterations
# [ INFO ] Duration:         30099.99 ms
# [ INFO ] Latency:
# [ INFO ]    Median:        69.34 ms
# [ INFO ]    Average:       70.51 ms
# [ INFO ]    Min:           48.82 ms
# [ INFO ]    Max:           222.65 ms
# [ INFO ] Throughput:   226.45 FPS

# %% [markdown]
# [ INFO ] Performance counts sorted for 0-th infer request
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.726      cpuTime (ms): 3.726     proportion: 5.29%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.647      cpuTime (ms): 3.647     proportion: 5.18%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.642      cpuTime (ms): 3.642     proportion: 5.18%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.639      cpuTime (ms): 3.639     proportion: 5.17%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.628      cpuTime (ms): 3.628     proportion: 5.16%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.626      cpuTime (ms): 3.626     proportion: 5.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.561      cpuTime (ms): 3.561     proportion: 5.06%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.528      cpuTime (ms): 3.528     proportion: 5.01%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.503      cpuTime (ms): 3.503     proportion: 4.98%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.502      cpuTime (ms): 3.502     proportion: 4.98%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.499      cpuTime (ms): 3.499     proportion: 4.97%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 3.476      cpuTime (ms): 3.476     proportion: 4.94%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.814      cpuTime (ms): 0.814     proportion: 1.16%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.814      cpuTime (ms): 0.814     proportion: 1.16%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.812      cpuTime (ms): 0.812     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.811      cpuTime (ms): 0.811     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.811      cpuTime (ms): 0.811     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.811      cpuTime (ms): 0.811     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.811      cpuTime (ms): 0.811     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.809      cpuTime (ms): 0.809     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.807      cpuTime (ms): 0.807     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.807      cpuTime (ms): 0.807     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.806      cpuTime (ms): 0.806     proportion: 1.15%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.805      cpuTime (ms): 0.805     proportion: 1.14%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.804      cpuTime (ms): 0.804     proportion: 1.14%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_f32      realTime (ms): 0.803      cpuTime (ms): 0.803     proportion: 1.14%
#
#
# Answer: Multi-Head Attention - FC layers

# %% [markdown]
# ### (Optional) Попробуйте подобрать параметры, чтобы увеличить FPS относительно

# %% [markdown]
# ## NNCF
#
# ### Дефолтная Квантизация (5 баллов)
#
# Квантизуйте модель с дефолтными параметрами. Замерьте accuracy.

# %%
calibration_dataset = load_dataset("glue", "sst2", split="train[:10%]")

# %%
import nncf

def transform_fn(sample):
    return {**tokenizer(sample["sentence"], return_tensors="pt")}

calibration_dataset = nncf.Dataset(calibration_dataset, transform_fn)
validation_dataset = nncf.Dataset(val_dataset, transform_fn)

# %%
#quntized_model = nncf.quantize(ov_model, calibration_dataset=calibration_dataset)
quantized_model = nncf.quantize(ov_model, calibration_dataset)
ov.save_model(quantized_model, "qbert.xml")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
compiled_model = ov.compile_model(quantized_model)
print(f"OpenVINO: {accuracy_evaluate(lambda x: compiled_model(x)[compiled_model.output()])}")
# Out:
# OpenVINO: {'accuracy': 0.8509174311926605}

# %% [markdown]
# Замерьте FPS квантизованной модели с помощью benchmark функции или benchmark_app:

# %%
! benchmark_app -m qbert.xml -t 30 -shape [1,128] -pc -pcsort "sort"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [Step 1/11] Parsing and validating input arguments
# [ INFO ] Parsing input parameters
# [Step 2/11] Loading OpenVINO Runtime
# [ INFO ] OpenVINO:
# [ INFO ] Build ................................. 2024.0.0-14509-34caeefd078-releases/2024/0
# [ INFO ]
# [ INFO ] Device info:
# [ INFO ] CPU
# [ INFO ] Build ................................. 2024.0.0-14509-34caeefd078-releases/2024/0
# [ INFO ]
# [ INFO ]
# [Step 3/11] Setting device configuration
# [ WARNING ] Performance hint was not explicitly specified in command line. Device(CPU) performance hint will be set to PerformanceMode.THROUGHPUT.
# [Step 4/11] Reading model files
# [ INFO ] Loading model files
# [ INFO ] Read model took 16.75 ms
# [ INFO ] Original model I/O parameters:
# [ INFO ] Model inputs:
# [ INFO ]     input_ids (node: input_ids) : i64 / [...] / [?,?]
# [ INFO ]     attention_mask (node: attention_mask) : i64 / [...] / [?,?]
# [ INFO ]     token_type_ids (node: token_type_ids) : i64 / [...] / [?,?]
# [ INFO ] Model outputs:
# [ INFO ]     logits (node: __module.classifier/aten::linear/Add) : f32 / [...] / [?,2]
# [Step 5/11] Resizing model to match image sizes and given batch
# [ INFO ] Model batch size: 1
# [ INFO ] Reshaping model: 'input_ids': [1,128], 'attention_mask': [1,128], 'token_type_ids': [1,128]
# [ INFO ] Reshape model took 3.93 ms
# [Step 6/11] Configuring input of the model
# [ INFO ] Model inputs:
# [ INFO ]     input_ids (node: input_ids) : i64 / [...] / [1,128]
# [ INFO ]     attention_mask (node: attention_mask) : i64 / [...] / [1,128]
# [ INFO ]     token_type_ids (node: token_type_ids) : i64 / [...] / [1,128]
# [ INFO ] Model outputs:
# [ INFO ]     logits (node: __module.classifier/aten::linear/Add) : f32 / [...] / [1,2]
# [Step 7/11] Loading the model to the device
# [ INFO ] Compile model took 316.09 ms
# [Step 8/11] Querying optimal runtime parameters
# [ INFO ] Model:
# [ INFO ]   NETWORK_NAME: Model622
# [ INFO ]   OPTIMAL_NUMBER_OF_INFER_REQUESTS: 16
# [ INFO ]   NUM_STREAMS: 16
# [ INFO ]   AFFINITY: Affinity.HYBRID_AWARE
# [ INFO ]   INFERENCE_NUM_THREADS: 20
# [ INFO ]   PERF_COUNT: YES
# [ INFO ]   INFERENCE_PRECISION_HINT: <Type: 'float32'>
# [ INFO ]   PERFORMANCE_HINT: THROUGHPUT
# [ INFO ]   EXECUTION_MODE_HINT: ExecutionMode.PERFORMANCE
# [ INFO ]   PERFORMANCE_HINT_NUM_REQUESTS: 0
# [ INFO ]   ENABLE_CPU_PINNING: True
# [ INFO ]   SCHEDULING_CORE_TYPE: SchedulingCoreType.ANY_CORE
# [ INFO ]   ENABLE_HYPER_THREADING: True
# [ INFO ]   EXECUTION_DEVICES: ['CPU']
# [ INFO ]   CPU_DENORMALS_OPTIMIZATION: False
# [ INFO ]   LOG_LEVEL: Level.NO
# [ INFO ]   CPU_SPARSE_WEIGHTS_DECOMPRESSION_RATE: 1.0
# [ INFO ]   DYNAMIC_QUANTIZATION_GROUP_SIZE: 0
# [ INFO ]   KV_CACHE_PRECISION: <Type: 'float16'>
# [Step 9/11] Creating infer requests and preparing input tensors
# [ WARNING ] No input files were given for input 'input_ids'!. This input will be filled with random values!
# [ WARNING ] No input files were given for input 'attention_mask'!. This input will be filled with random values!
# [ WARNING ] No input files were given for input 'token_type_ids'!. This input will be filled with random values!
# [ INFO ] Fill input 'input_ids' with random values
# [ INFO ] Fill input 'attention_mask' with random values
# [ INFO ] Fill input 'token_type_ids' with random values
# [Step 10/11] Measuring performance (Start inference asynchronously, 16 inference requests, limits: 30000 ms duration)
# [ INFO ] Benchmarking in inference only mode (inputs filling are not included in measurement loop).
# [ INFO ] First inference took 20.18 ms
# [Step 11/11] Dumping statistics report
# [ INFO ] Performance counts sorted for 0-th infer request
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 1.193      cpuTime (ms): 1.193     proportion: 4.78%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 1.186      cpuTime (ms): 1.186     proportion: 4.76%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 1.184      cpuTime (ms): 1.184     proportion: 4.75%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 1.182      cpuTime (ms): 1.182     proportion: 4.74%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 1.182      cpuTime (ms): 1.182     proportion: 4.74%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 1.181      cpuTime (ms): 1.181     proportion: 4.74%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.819      cpuTime (ms): 0.819     proportion: 3.28%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.816      cpuTime (ms): 0.816     proportion: 3.27%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.814      cpuTime (ms): 0.814     proportion: 3.26%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.814      cpuTime (ms): 0.814     proportion: 3.26%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.813      cpuTime (ms): 0.813     proportion: 3.26%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.812      cpuTime (ms): 0.812     proportion: 3.26%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.455      cpuTime (ms): 0.455     proportion: 1.82%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.453      cpuTime (ms): 0.453     proportion: 1.82%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.453      cpuTime (ms): 0.453     proportion: 1.82%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.448      cpuTime (ms): 0.448     proportion: 1.80%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.447      cpuTime (ms): 0.447     proportion: 1.79%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.444      cpuTime (ms): 0.444     proportion: 1.78%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.295      cpuTime (ms): 0.295     proportion: 1.18%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.266      cpuTime (ms): 0.266     proportion: 1.07%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.266      cpuTime (ms): 0.266     proportion: 1.07%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.266      cpuTime (ms): 0.266     proportion: 1.07%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.265      cpuTime (ms): 0.265     proportion: 1.06%
# __module.bert.en...  Status.EXECUTED      layerType: Softmax              execType: jit_avx2_f32         realTime (ms): 0.265      cpuTime (ms): 0.265     proportion: 1.06%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.225      cpuTime (ms): 0.225     proportion: 0.90%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.223      cpuTime (ms): 0.223     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.223      cpuTime (ms): 0.223     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.223      cpuTime (ms): 0.223     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.223      cpuTime (ms): 0.223     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.223      cpuTime (ms): 0.223     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.223      cpuTime (ms): 0.223     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.223      cpuTime (ms): 0.223     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.223      cpuTime (ms): 0.223     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.223      cpuTime (ms): 0.223     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.223      cpuTime (ms): 0.223     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.222      cpuTime (ms): 0.222     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.222      cpuTime (ms): 0.222     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.222      cpuTime (ms): 0.222     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.222      cpuTime (ms): 0.222     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.222      cpuTime (ms): 0.222     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.222      cpuTime (ms): 0.222     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.222      cpuTime (ms): 0.222     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.222      cpuTime (ms): 0.222     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.221      cpuTime (ms): 0.221     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.221      cpuTime (ms): 0.221     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.221      cpuTime (ms): 0.221     proportion: 0.89%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.220      cpuTime (ms): 0.220     proportion: 0.88%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.220      cpuTime (ms): 0.220     proportion: 0.88%
# Multiply_8817        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.193      cpuTime (ms): 0.193     proportion: 0.77%
# Multiply_9897        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.098      cpuTime (ms): 0.098     proportion: 0.39%
# Multiply_10257       Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.098      cpuTime (ms): 0.098     proportion: 0.39%
# Multiply_9177        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.089      cpuTime (ms): 0.089     proportion: 0.36%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: brgemm_avx2_I8       realTime (ms): 0.088      cpuTime (ms): 0.088     proportion: 0.35%
# Multiply_9537        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.088      cpuTime (ms): 0.088     proportion: 0.35%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: brgemm_avx2_I8       realTime (ms): 0.088      cpuTime (ms): 0.088     proportion: 0.35%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: brgemm_avx2_I8       realTime (ms): 0.088      cpuTime (ms): 0.088     proportion: 0.35%
# Multiply_10617       Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.088      cpuTime (ms): 0.088     proportion: 0.35%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: brgemm_avx2_I8       realTime (ms): 0.087      cpuTime (ms): 0.087     proportion: 0.35%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: brgemm_avx2_I8       realTime (ms): 0.087      cpuTime (ms): 0.087     proportion: 0.35%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: brgemm_avx2_I8       realTime (ms): 0.087      cpuTime (ms): 0.087     proportion: 0.35%
# __module.bert.em...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_i8          realTime (ms): 0.079      cpuTime (ms): 0.079     proportion: 0.32%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.077      cpuTime (ms): 0.077     proportion: 0.31%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.064      cpuTime (ms): 0.064     proportion: 0.26%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.064      cpuTime (ms): 0.064     proportion: 0.26%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.064      cpuTime (ms): 0.064     proportion: 0.26%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.062      cpuTime (ms): 0.062     proportion: 0.25%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.062      cpuTime (ms): 0.062     proportion: 0.25%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.038      cpuTime (ms): 0.038     proportion: 0.15%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.037      cpuTime (ms): 0.037     proportion: 0.15%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.037      cpuTime (ms): 0.037     proportion: 0.15%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.037      cpuTime (ms): 0.037     proportion: 0.15%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.037      cpuTime (ms): 0.037     proportion: 0.15%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.035      cpuTime (ms): 0.035     proportion: 0.14%
# __module.bert.em...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.033      cpuTime (ms): 0.033     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.033      cpuTime (ms): 0.033     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.033      cpuTime (ms): 0.033     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.033      cpuTime (ms): 0.033     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.033      cpuTime (ms): 0.033     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.033      cpuTime (ms): 0.033     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.033      cpuTime (ms): 0.033     proportion: 0.13%
# __module.bert.em...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_f32         realTime (ms): 0.032      cpuTime (ms): 0.032     proportion: 0.13%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.12%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.12%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.12%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.12%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.12%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.12%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.12%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.12%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.12%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.12%
# __module.bert.en...  Status.EXECUTED      layerType: MVN                  execType: jit_avx2_i8          realTime (ms): 0.031      cpuTime (ms): 0.031     proportion: 0.12%
# Multiply_8365        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_I8          realTime (ms): 0.018      cpuTime (ms): 0.018     proportion: 0.07%
# Multiply_8505        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_I8          realTime (ms): 0.018      cpuTime (ms): 0.018     proportion: 0.07%
# Multiply_8327        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_I8          realTime (ms): 0.017      cpuTime (ms): 0.017     proportion: 0.07%
# Multiply_8683        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_i8          realTime (ms): 0.017      cpuTime (ms): 0.017     proportion: 0.07%
# Multiply_8400        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_I8          realTime (ms): 0.017      cpuTime (ms): 0.017     proportion: 0.07%
# Multiply_9464        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_i8          realTime (ms): 0.017      cpuTime (ms): 0.017     proportion: 0.07%
# __module.bert.po...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.017      cpuTime (ms): 0.017     proportion: 0.07%
# Multiply_9104        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_i8          realTime (ms): 0.016      cpuTime (ms): 0.016     proportion: 0.06%
# Multiply_10544       Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_i8          realTime (ms): 0.016      cpuTime (ms): 0.016     proportion: 0.06%
# Multiply_8470        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_I8          realTime (ms): 0.013      cpuTime (ms): 0.013     proportion: 0.05%
# Multiply_8435        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_I8          realTime (ms): 0.012      cpuTime (ms): 0.012     proportion: 0.05%
# Multiply_9824        Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_i8          realTime (ms): 0.010      cpuTime (ms): 0.010     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.009      cpuTime (ms): 0.009     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.009      cpuTime (ms): 0.009     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.009      cpuTime (ms): 0.009     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.009      cpuTime (ms): 0.009     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.009      cpuTime (ms): 0.009     proportion: 0.04%
# Multiply_10184       Status.EXECUTED      layerType: Subgraph             execType: jit_avx2_i8          realTime (ms): 0.009      cpuTime (ms): 0.009     proportion: 0.04%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.009      cpuTime (ms): 0.009     proportion: 0.04%
# __module.bert.em...  Status.EXECUTED      layerType: Gather               execType: ref_any_i8           realTime (ms): 0.008      cpuTime (ms): 0.008     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.008      cpuTime (ms): 0.008     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.008      cpuTime (ms): 0.008     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.008      cpuTime (ms): 0.008     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.008      cpuTime (ms): 0.008     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.008      cpuTime (ms): 0.008     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.008      cpuTime (ms): 0.008     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.007      cpuTime (ms): 0.007     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.007      cpuTime (ms): 0.007     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_I8           realTime (ms): 0.007      cpuTime (ms): 0.007     proportion: 0.03%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_I8           realTime (ms): 0.006      cpuTime (ms): 0.006     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.006      cpuTime (ms): 0.006     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_I8           realTime (ms): 0.006      cpuTime (ms): 0.006     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.006      cpuTime (ms): 0.006     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_I8           realTime (ms): 0.006      cpuTime (ms): 0.006     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.006      cpuTime (ms): 0.006     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_I8           realTime (ms): 0.006      cpuTime (ms): 0.006     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_I8           realTime (ms): 0.006      cpuTime (ms): 0.006     proportion: 0.02%
# __module.bert.en...  Status.EXECUTED      layerType: Transpose            execType: unknown_i8           realTime (ms): 0.006      cpuTime (ms): 0.006     proportion: 0.02%
# __module.classif...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.004      cpuTime (ms): 0.004     proportion: 0.02%
# __module.bert.em...  Status.EXECUTED      layerType: Convert              execType: ref_i64              realTime (ms): 0.003      cpuTime (ms): 0.003     proportion: 0.01%
# __module.bert/at...  Status.EXECUTED      layerType: Convert              execType: ref_i32              realTime (ms): 0.002      cpuTime (ms): 0.002     proportion: 0.01%
# __module.bert.em...  Status.EXECUTED      layerType: Gather               execType: ref_any_i8           realTime (ms): 0.002      cpuTime (ms): 0.002     proportion: 0.01%
# Convert_7937         Status.EXECUTED      layerType: Convert              execType: ref_i64              realTime (ms): 0.001      cpuTime (ms): 0.001     proportion: N/A%
# __module.bert.em...  Status.EXECUTED      layerType: Convert              execType: ref_i64              realTime (ms): 0.001      cpuTime (ms): 0.001     proportion: N/A%
# input_ids            Status.NOT_RUN       layerType: Parameter            execType: unknown_i64          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# attention_mask       Status.NOT_RUN       layerType: Parameter            execType: unknown_i64          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert/at...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# token_type_ids       Status.NOT_RUN       layerType: Parameter            execType: unknown_i64          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_I8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_I8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_I8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_I8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_I8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_I8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.po...  Status.NOT_RUN       layerType: Gather               execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.po...  Status.NOT_RUN       layerType: Tanh                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.po...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Result_986179        Status.NOT_RUN       layerType: Result               execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Total time:       24.940 milliseconds
# Total CPU time:   24.940 milliseconds
# Total proportion: 100.00 %
#
# [ INFO ] Performance counts sorted for 1-th infer request
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 1.197      cpuTime (ms): 1.197     proportion: 4.77%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 1.197      cpuTime (ms): 1.197     proportion: 4.77%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 1.190      cpuTime (ms): 1.190     proportion: 4.75%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 1.190      cpuTime (ms): 1.190     proportion: 4.75%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 1.189      cpuTime (ms): 1.189     proportion: 4.74%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 1.185      cpuTime (ms): 1.185     proportion: 4.73%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.823      cpuTime (ms): 0.823     proportion: 3.28%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.822      cpuTime (ms): 0.822     proportion: 3.28%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.819      cpuTime (ms): 0.819     proportion: 3.27%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.817      cpuTime (ms): 0.817     proportion: 3.26%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.816      cpuTime (ms): 0.816     proportion: 3.25%
# __module.bert.en...  Status.EXECUTED      layerType: FullyConnected       execType: brgemm_avx2_i8       realTime (ms): 0.812      cpuTime (ms): 0.812     proportion: 3.24%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.462      cpuTime (ms): 0.462     proportion: 1.84%
# __module.bert.en...  Status.EXECUTED      layerType: MatMul               execType: jit_gemm_f32         realTime (ms): 0.460      cpuTime (ms): 0.460     proportion: 1.83%
# ...
# __module.bert/at...  Status.EXECUTED      layerType: Convert              execType: ref_i32              realTime (ms): 0.002      cpuTime (ms): 0.002     proportion: 0.01%
# __module.bert.em...  Status.EXECUTED      layerType: Convert              execType: ref_i64              realTime (ms): 0.001      cpuTime (ms): 0.001     proportion: N/A%
# input_ids            Status.NOT_RUN       layerType: Parameter            execType: unknown_i64          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# attention_mask       Status.NOT_RUN       layerType: Parameter            execType: unknown_i64          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert/at...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# token_type_ids       Status.NOT_RUN       layerType: Parameter            execType: unknown_i64          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_I8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_I8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_I8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_I8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_I8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_I8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Reshape              execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: Gelu                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.en...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.po...  Status.NOT_RUN       layerType: Gather               execType: unknown_i8           realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.po...  Status.NOT_RUN       layerType: Tanh                 execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# __module.bert.po...  Status.NOT_RUN       layerType: FakeQuantize         execType: undef                realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Result_986179        Status.NOT_RUN       layerType: Result               execType: unknown_f32          realTime (ms): 0.000      cpuTime (ms): 0.000     proportion: N/A%
# Total time:       24.896 milliseconds
# Total CPU time:   24.896 milliseconds
# Total proportion: 100.00 %
#
# [ INFO ] Execution Devices:['CPU']
# [ INFO ] Count:            17328 iterations
# [ INFO ] Duration:         30052.64 ms
# [ INFO ] Latency:
# [ INFO ]    Median:        25.67 ms
# [ INFO ]    Average:       27.65 ms
# [ INFO ]    Min:           19.55 ms
# [ INFO ]    Max:           111.23 ms
# [ INFO ] Throughput:   576.59 FPS

# %% [markdown]
# ### Accuracy Control (10 баллов)
#
# Квантизуйте модель так, чтобы потеря accuracy была в пределах 1%. Замерьте FPS получившейся модели.

# %%
def validate(model, dataset):
    accuracy = evaluate.load("accuracy") 
    for i, sample in enumerate(dataset):
        if i >=499:
            break
        tokenized = {**tokenizer(sample["sentence"], return_tensors="pt")}
        logits = model(tokenized)[model.output()]
        pred = np.argmax(logits, axis=1)
        accuracy.add(references=sample["label"], predictions=pred)

    return accuracy.compute()['accuracy']



quntized_model = nncf.quantize_with_accuracy_control(ov_model, 
                                                     calibration_dataset=calibration_dataset, 
                                                     validation_dataset=validation_dataset, 
                                                     validation_fn=validate)

ov.save_model(quntized_model, "qbert.xml")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:nncf:Validation of initial model was started
# INFO:nncf:Elapsed Time: 00:00:00
# INFO:nncf:Elapsed Time: 00:00:05
# INFO:nncf:Metric of initial model: 0.9078156312625251
# INFO:nncf:Collecting values for each data item using the initial model
# INFO:nncf:Elapsed Time: 00:19:56
# INFO:nncf:Validation of quantized model was started
# INFO:nncf:Elapsed Time: 00:00:00
# INFO:nncf:Elapsed Time: 00:00:03
# INFO:nncf:Metric of quantized model: 0.843687374749499
# INFO:nncf:Collecting values for each data item using the quantized model
# INFO:nncf:Elapsed Time: 00:19:53
# INFO:nncf:Accuracy drop: 0.06412825651302612 (absolute)
# INFO:nncf:Accuracy drop: 0.06412825651302612 (absolute)
# INFO:nncf:Total number of quantized operations in the model: 85
# INFO:nncf:Number of parallel workers to rank quantized operations: 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 15
#       9         accuracy.add(references=sample["label"], predictions=pred)
#      11     return accuracy.compute()['accuracy']
# ---> 15 quntized_model = nncf.quantize_with_accuracy_control(ov_model,
#      16                                                      calibration_dataset=calibration_dataset,
#      17                                                      validation_dataset=validation_dataset,
#      18                                                      validation_fn=validate)
#      20 ov.save_model(quntized_model, "qbert.xml")
#
# File ~/.local/lib/python3.10/site-packages/nncf/quantization/quantize_model.py:230, in quantize_with_accuracy_control(model, calibration_dataset, validation_dataset, validation_fn, max_drop, drop_type, preset, target_device, subset_size, fast_bias_correction, model_type, ignored_scope, advanced_quantization_parameters, advanced_accuracy_restorer_parameters)
#     227 if backend == BackendType.OPENVINO:
#     228     from nncf.openvino.quantization.quantize_model import quantize_with_accuracy_control_impl
# --> 230     return quantize_with_accuracy_control_impl(
#     231         model,
#     232         calibration_dataset,
#     233         validation_dataset,
#     234         validation_fn,
#     235         max_drop,
#     236         drop_type,
#     237         preset,
#     238         target_device,
#     239         subset_size,
#     240         fast_bias_correction,
#     241         model_type,
#     242         ignored_scope,
#     243         advanced_quantization_parameters,
#     244         advanced_accuracy_restorer_parameters,
#     245     )
#     246 if backend == BackendType.ONNX:
#     247     from nncf.onnx.quantization.quantize_model import quantize_with_accuracy_control_impl
#
# File ~/.local/lib/python3.10/site-packages/nncf/openvino/quantization/quantize_model.py:378, in quantize_with_accuracy_control_impl(model, calibration_dataset, validation_dataset, validation_fn, max_drop, drop_type, preset, target_device, subset_size, fast_bias_correction, model_type, ignored_scope, advanced_quantization_parameters, advanced_accuracy_restorer_parameters)
#     374 quantize_with_accuracy_control_fn = native_quantize_with_accuracy_control_impl
#     376 val_func = wrap_validation_fn(validation_fn)
# --> 378 return quantize_with_accuracy_control_fn(
#     379     model,
#     380     calibration_dataset,
#     381     validation_dataset,
#     382     val_func,
#     383     max_drop,
#     384     drop_type,
#     385     preset,
#     386     target_device,
#     387     subset_size,
#     388     fast_bias_correction,
#     389     model_type,
#     390     ignored_scope,
#     391     advanced_quantization_parameters,
#     392     advanced_accuracy_restorer_parameters,
#     393 )
#
# File ~/.local/lib/python3.10/site-packages/nncf/telemetry/decorator.py:72, in tracked_function.__call__.<locals>.wrapped(*args, **kwargs)
#      64     for event in events:
#      65         telemetry.send_event(
#      66             event_category=category,
#      67             event_action=event.name,
#      68             event_label=event.data,
#      69             event_value=event.int_data,
#      70         )
# ---> 72 retval = fn(*args, **kwargs)
#      74 if category is not None and category != previous_category:
#      75     telemetry.end_session(self._category)
#
# File ~/.local/lib/python3.10/site-packages/nncf/openvino/quantization/quantize_model.py:271, in native_quantize_with_accuracy_control_impl(model, calibration_dataset, validation_dataset, validation_fn, max_drop, drop_type, preset, target_device, subset_size, fast_bias_correction, model_type, ignored_scope, advanced_quantization_parameters, advanced_accuracy_restorer_parameters)
#     261         ranking_subset_size = advanced_accuracy_restorer_parameters.ranking_subset_size
#     263     accuracy_restorer = QuantizationAccuracyRestorer(
#     264         ranking_subset_size,
#     265         advanced_accuracy_restorer_parameters.max_num_iterations,
#    (...)
#     269         advanced_accuracy_restorer_parameters.restore_mode,
#     270     )
# --> 271     quantized_model = accuracy_restorer.apply(
#     272         model,
#     273         initial_metric_results,
#     274         quantized_model,
#     275         quantized_metric_results,
#     276         validation_dataset,
#     277         validation_dataset_size,
#     278         evaluator,
#     279     )
#     281 if compress_weights:
#     282     compress_quantize_weights_transformation(quantized_model)
#
# File ~/.local/lib/python3.10/site-packages/nncf/quantization/algorithms/accuracy_control/algorithm.py:214, in QuantizationAccuracyRestorer.apply(self, initial_model, initial_metric_results, quantized_model, quantized_metric_results, validation_dataset, validation_dataset_size, evaluator)
#     211 nncf_logger.info(f"Accuracy drop: {accuracy_drop} ({self.drop_type})")
#     213 # Accuracy drop is greater than the maximum drop so we need to restore accuracy
# --> 214 return self._apply(
#     215     initial_model,
#     216     initial_metric_results,
#     217     quantized_model,
#     218     quantized_metric_results,
#     219     validation_dataset,
#     220     validation_dataset_size,
#     221     evaluator,
#     222     accuracy_drop,
#     223     algo_backend,
#     224 )
#
# File ~/.local/lib/python3.10/site-packages/nncf/quantization/algorithms/accuracy_control/algorithm.py:288, in QuantizationAccuracyRestorer._apply(self, initial_model, initial_metric_results, quantized_model, quantized_metric_results, validation_dataset, validation_dataset_size, evaluator, accuracy_drop, algo_backend)
#     285 nncf_logger.info(f"Number of parallel workers to rank quantized operations: {num_ranking_workers}")
#     287 ranker = Ranker(self.ranking_subset_size, validation_dataset, algo_backend, evaluator, num_ranking_workers)
# --> 288 groups_to_rank = ranker.find_groups_of_quantizers_to_rank(quantized_model_graph)
#     289 ranked_groups = ranker.rank_groups_of_quantizers(
#     290     groups_to_rank,
#     291     quantized_model,
#    (...)
#     294     quantized_metric_results.values_for_each_item,
#     295 )
#     297 previous_model = quantized_model
#
# File ~/.local/lib/python3.10/site-packages/nncf/quantization/algorithms/accuracy_control/ranker.py:116, in Ranker.find_groups_of_quantizers_to_rank(self, quantized_model_graph)
#     114 if processed.get(quantizer_node.node_name, False):
#     115     continue
# --> 116 group, operations = find_quantizer_nodes_to_cut(
#     117     quantized_model_graph_without_shapeof,
#     118     quantizer_node,
#     119     self._algo_backend.get_quantizer_metatypes(),
#     120     self._algo_backend.get_const_metatypes(),
#     121     self._algo_backend.get_quantizable_metatypes(),
#     122     self._algo_backend.get_quantize_agnostic_metatypes(),
#     123 )
#     124 for x in group:
#     125     processed[x.node_name] = True
#
# File ~/.local/lib/python3.10/site-packages/nncf/common/quantization/quantizer_removal.py:94, in find_quantizer_nodes_to_cut(graph, quantizer_node, quantizer_metatypes, const_metatypes, quantizable_metatypes, quantize_agnostic_metatypes)
#      92 while to_see_parents or to_see_children:
#      93     if to_see_children:
# ---> 94         _parse_node_relatives(to_see_children.pop(), is_parents=False)
#      95     if to_see_parents:
#      96         _parse_node_relatives(to_see_parents.pop(), is_parents=True)
#
# File ~/.local/lib/python3.10/site-packages/nncf/common/quantization/quantizer_removal.py:56, in find_quantizer_nodes_to_cut.<locals>._parse_node_relatives(node, is_parents)
#      53 if node.metatype in quantizable_metatypes:
#      54     ops_to_return_in_orig_prec.add(node)
# ---> 56 relatives = graph.get_previous_nodes(node) if is_parents else graph.get_next_nodes(node)
#      57 for relative in relatives:
#      58     if relative.metatype in quantizer_metatypes:
#
# File ~/.local/lib/python3.10/site-packages/nncf/common/graph/graph.py:318, in NNCFGraph.get_next_nodes(self, node)
#     311 def get_next_nodes(self, node: NNCFNode) -> List[NNCFNode]:
#     312     """
#     313     Returns consumer nodes of provided node.
#     314
#     315     :param node: Producer node.
#     316     :return: List of consumer nodes of provided node.
#     317     """
# --> 318     nx_node_keys = self._nx_graph.succ[self._node_id_to_key_dict[node.node_id]]
#     319     return [self._nodes[key] for key in nx_node_keys]
#
# KeyError: 499

# %%
! benchmark_app -m qbert.xml -t 30 -shape [1,128] -pc -pcsort "sort"

# %% [markdown]
# # Дополнительно (2 балла)
#
# Добавьте в модель:
# 1. Токенизационный препроцессинг с помощью `openvino-tokenizers`
# 2. (Hard) Добавьте постпроцессинг в модель, чтобы она сразу отдавала результат `np.argmax(logits, axis=1)`

# %%
# !pip install --pre -U openvino-tokenizers --extra-index-url https://storage.openvinotoolkit.org/simple/wheels/nightly git+https://github.com/openvinotoolkit/nncf.git
